# %% [markdown]
# # **Module 3a Programming Workshop**

# %% [markdown]
# ## Group Roster
# 1. Monica Willson
# 2. Amro Osman

# %% [markdown]
# ## **`igpay()` Redux**
#
# Versions A and B are "solutions" for the `igpay()` exercise at the end of Lesson 6.
#
# **Read and run both versions to make sure they work correctly. Debug as necessary. Then explain how the logic for each works.**

# %% [markdown]
# YOUR ANSWER HERE.

# %%
def char_rotate(x):
  return x[1:]+x[0]

# %%
char_rotate("monica willson") # takes the first character and moves it to the end
# Out:
# 'onica willsonm'

# %% [markdown]
# Hints:
# - Use your `char_rotate()` function from exercise 2.
# - There may be a string method or two that can simplify your code.
# - `igpay("pig")` is "IGPAY"
# - `igpay("art")` is "ARTAY"
# - `igpay("thx")` is "thx"
# - `igpay("")`  is ""

# %%
# Version A

def igpayA(x):
  if x == "":
    return x # if x is an empty string return empty string
  x = x.upper() # convert every letter to upper case, latin does not have lowercase letters
  vowel = "AEIOU" # set variable to contain all vowels
  if x[0] in vowel: 
    return x + "YAY" # if words starts with a vowel then add "YAY" to the end of word
  i= 0
  while x[0] not in vowel: # if word starts with one or more consonants in a row
    x = char_rotate(x) # then move consonants to the end 
    i += 1   ### is a while loop appropriate here? we need to iterate through the string x what would be the counter?
    if i == x:
      return len(x)
  return x + "AY"

igpayA("pig") # worked!
# Out:
# 'IGPAY'

# %%
igpayA('art') # 'art' input didn't work here only the first if statement return was executed here
# Out:
# 'ARTYAY'

# %%
igpayA('thx') # runtime error because we have all consonants
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f10397068be1> in <module>
# ----> 1 igpayA('thx')
#
# <ipython-input-6-8d741d09c2fc> in igpayA(x)
#      10   i= 0
#      11   while x[0] not in vowel: # if word starts with one or more consonants in a row
# ---> 12     x = char_rotate(x) # then move consonants to the end
#      13     i += 1   # is a while loop appropriate here?
#      14     if i == x:
#
# <ipython-input-2-69e3e0560f05> in char_rotate(x)
#       1 def char_rotate(x):
# ----> 2   return x[1:]+x[0]
#
# KeyboardInterrupt:

# %%
# Version B
def igpayB(word): # define our pig latin function 
  if word == "":  # if input string is an empty string 
    return word   # return the empty string
  w = word.upper() # convert all elements in the string to uppercases
  vowal = "AEIOU"  # set a variable that contains all vowal characters

  if w[0] in vowal:  # if our string starts with a character in vowal
      return w + "YAY"  # append to the string "YAY"
  for i in w: # iterate through the characters of word string
    if w[0] not in vowal: # if the first character of the string is a consonant
      w = char_rotate(w)  # place the first character that is a consonant to the end of the string 
    if w[0] in vowal:     # if the first character of the string is a vowal 
      return w + "AY"     #  append to the string "AY"
  return w
igpayB("pig")
# Out:
# 'IGPAY'

# %%
# IN CLASS Convert a full sentence to pig latin using the function 'igpay'
def igpay_sentence(s): # input changed to a sentence
    words = s.split(" ")  # splits a string into list of words split based on an empty string
    print(words) 
    out = ''  # initialize an output string 
    for w in words: # iterate through character 'w' in sentence 'words'
        out += igpayB(w) + " " # append to the output string each word in pig latin
    return out[:-1]  # return all characters of output string but the last which is an empty character
igpay_sentence("The rain in spain is mostly in the plain")
# Out:
# ['The', 'rain', 'in', 'spain', 'is', 'mostly', 'in', 'the', 'plain']
# 'ETHAY AINRAY INYAY AINSPAY ISYAY OSTLYMAY INYAY ETHAY AINPLAY'

# %%
def igpay_sentence(s): # a positional (required) argument is a sentence 's'
    '''
    A 2nd alternative of the above code block. 
    The input sentence 's' is converted into pig latin
    '''
    words = s.split(" ") # splits a string into list of words split based on an empty string
    print(words) 
    igs = [igpayB(w) for w in words] # iterate through each element in the list words and apply to each word the pig latin function
    print(igs) 
    return " ".join(igs)  # with the list 'igs' join each element of the list into a string. Join on empty string
igpay_sentence("The rain in spain is mostly in the plain")
# Out:
# ['The', 'rain', 'in', 'spain', 'is', 'mostly', 'in', 'the', 'plain']
# ['ETHAY', 'AINRAY', 'INYAY', 'AINSPAY', 'ISYAY', 'OSTLYMAY', 'INYAY', 'ETHAY', 'AINPLAY']
# 'ETHAY AINRAY INYAY AINSPAY ISYAY OSTLYMAY INYAY ETHAY AINPLAY'

# %% [markdown]
# **Write the *shortest code you can* that converts sentences like "The rain in spain is mostly in the plain" to pig latin.** You may use one of the `igpay()` functions as needed.

# %%
def igpay_sentence(s): 
    '''
    A 3rd alternative of the above code block. 
    The input sentence 's' is converted into pig latin
    Combines the above statement of the function into a
    one liner
    '''
    return " ".join([igpayB(w) for w in s.split(" ")]) 
                    
igpay_sentence("The rain in spain is mostly in the plain")
# Out:
# 'ETHAY AINRAY INYAY AINSPAY ISYAY OSTLYMAY INYAY ETHAY AINPLAY'

# %% [markdown]
# ## **Roman Numerals (the hard way)**
# Write a function called `roman2int()` that converts a roman numeral string to an integer. So, `roman2int("XXIX")` returns 29 and `roman2int("MCMXCIX")` returns 1999.
#
# Requirements:
# - The function has a single parameter called `roman_numeral` that must be a string.
# - Iterate over the string with a `while` loop with two loop variables and a stopping condition:
#   - `int_value` is an accumulator for the integer value of the roman characters processed so far.
#   - `remaining` is used to keep track of the romain characters remaining. It is like the `digits` variable we used wth long division.
#   - The loop terminates when `remaining` is an empty string.
#   - Don't forget to initialize the variables before entering the loop.
# - Each pass through, use a slice or string method to compare the head of `remaining` with one of the following patterns (with integer equivalents provided):
#   - "IV" = 4
#   - "IX" = 9
#   - "XL" = 40
#   - "XC" = 90
#   - "CD" = 400
#   - "CM" = 900
#   - "I" = 1
#   - "V" = 5
#   - "X" = 10
#   - "L" = 50
#   - "C" = 100
#   - "D" = 500
#   - "M" = 1000
#   - any other character = 0
# - Compare the patterns in the order given above using an `if ... elif` statement with 14 clauses. If a pattern matches then
#   - Update `int_value` by adding the appropriate integer.
#   - Update `remaining` by removing the matched pattern from the head of string. Note: you can do with with a slice to the right of the `=`.

# %%
def roman2int(roman_numeral): #positional argument is a string of roman numeral characters
    int_value  = 0 #initialize accumulator total numerical sum 
    remaining = roman_numeral # counter variable is the character in the roman numerical  
    while remaining: # if characters remain in the roman_numeral
        if remaining[0:2] == "IV": # if the first two characters of roman_numeral are "IV"
            int_value += 4         # update the accumulator total numerical sum of 'int_value'
            remaining = remaining[2:]  # update the remaining characters of 'roman_numeral' slicing off the first two characters

        elif remaining[0:2] == "IX":
            int_value += 9 
            remaining = remaining[2:]
        
        elif remaining[0:2] == "XL":
            int_value += 40 
            remaining = remaining[2:]
        
        elif remaining[0:2] == "XC":
            int_value += 90 
            remaining = remaining[2:]
        
        elif remaining[0:2] == "CD":
            int_value += 400 
            remaining = remaining[2:] 
        
        elif remaining[0:2] == "CM":
            int_value += 900
            remaining = remaining[2:]
          
        elif remaining[0] == "I":  # if first character of roman_numeral is "I"
            int_value += 1           # update the numerical sum of 'int_value'
            remaining = remaining[1:] # update the remaining characters of 'roman_numeral' slicing off the first character
        
        elif remaining[0] == "V":
            int_value += 5
            remaining = remaining[1:]
         
        elif remaining[0] == "X":
            int_value += 10
            remaining = remaining[1:]

        elif remaining[0] == "L":
            int_value += 50
            remaining = remaining[1:]
        
        elif remaining[0] == "C":
            int_value += 100
            remaining = remaining[1:]

        elif remaining[0] == "D":
            int_value += 500
            remaining = remaining[1:]

        elif remaining[0] == "M":
            int_value += 1000
            remaining = remaining[1:]

        else:
            remaining = remaining[1:]

    return int_value    # after all characters of roman_numeral have been exhausted return the total numerical sum of 'roman_numeral'


# Function call testing "XXIX"
roman2int("XXIX")
# Out:
# 29

# %%
# Function call testing "MCMXCIX"
roman2int("MCMXCIX")
# Out:
# 1999
